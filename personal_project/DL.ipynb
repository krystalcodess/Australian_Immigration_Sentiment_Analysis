# %%
pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from tensorflow) (4.25.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from tensorflow) (1.65.4)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (1.25.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from keras>=3.2.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.6.2)
# Requirement already satisfied: markdown>=2.6.8 in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from rich->keras>=3.2.0->tensorflow) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/d.o.npat/Library/Python/3.11/lib/python/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import pickle
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense, Dropout
from tensorflow.keras.layers import Input, Dense, Embedding, Conv2D, MaxPool2D
from tensorflow.keras.layers import Reshape, Flatten, Dropout, Concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from sklearn.metrics import f1_score, precision_score, recall_score
import warnings
from preprocessing import (
    preprocessing,
    convert_text_to_vector,
    convert_text_to_label
)
warnings.filterwarnings("ignore")

# %%
df_twitter = pd.read_csv('/Users/d.o.npat/Desktop/personal_project/cleaned_twitter_data.csv')
df_guardian = pd.read_csv('/Users/d.o.npat/Desktop/personal_project/cleaned_guardian_df.csv')


inputs_twitter = df_twitter['text'].values.tolist()
labels_twitter = df_twitter['sentiment'].values.tolist()

inputs_guardian = df_guardian['text'].values.tolist()
labels_guardian = df_guardian['sentiment'].values.tolist()

inputs = inputs_twitter + inputs_guardian
labels = labels_twitter + labels_guardian

inputs = list(map(preprocessing, inputs))

data = convert_text_to_vector(inputs)
labels = convert_text_to_label(labels)

# %%
X_train, X_test, y_train, y_test = train_test_split(inputs, labels, test_size=0.2, random_state=42)

# %%
max_words = 10000
max_sequence_length = 100
tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(X_train)
X_train_sequence = tokenizer.texts_to_sequences(X_train)
X_test_sequence = tokenizer.texts_to_sequences(X_test)
X_train_padded = tf.keras.preprocessing.sequence.pad_sequences(X_train_sequence, maxlen=max_sequence_length)
X_test_padded = tf.keras.preprocessing.sequence.pad_sequences(X_test_sequence, maxlen=max_sequence_length)

tokenizer_filename = 'tokenizer.pkl'
with open(tokenizer_filename, 'wb') as tokenizer_file:
    pickle.dump(tokenizer, tokenizer_file)

# %%
embedding_dim = 100
batch_size = 256
epochs = 80
drop = 0.5

# %%
model = Sequential()
model.add(Embedding(max_words, embedding_dim, input_length=max_sequence_length))
model.add(LSTM(100))
model.add(Dropout(drop))
model.add(Dense(3, activation='softmax'))

adam = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, weight_decay=0.0)
model.compile(loss='sparse_categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
history = model.fit(X_train_padded, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)

test_loss, test_accuracy = model.evaluate(X_test_padded, y_test, verbose=1)
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy:.4f}')

y_test_pred = model.predict(X_test_padded)
y_test_pred_classes = np.argmax(y_test_pred, axis=1)

f1 = f1_score(y_test, y_test_pred_classes, average='weighted')
precision = precision_score(y_test, y_test_pred_classes, average='weighted')
recall = recall_score(y_test, y_test_pred_classes, average='weighted')
print(f'F1 Score: {f1:.4f}')
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
# Out:
# Epoch 1/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 278ms/step - accuracy: 0.4169 - loss: 1.0935 - val_accuracy: 0.6441 - val_loss: 1.0487
# Epoch 2/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - accuracy: 0.5947 - loss: 1.0465 - val_accuracy: 0.6271 - val_loss: 0.9303
# Epoch 3/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 209ms/step - accuracy: 0.5667 - loss: 0.9471 - val_accuracy: 0.6271 - val_loss: 0.8360
# Epoch 4/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 191ms/step - accuracy: 0.5490 - loss: 0.9232 - val_accuracy: 0.6271 - val_loss: 0.8346
# Epoch 5/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 230ms/step - accuracy: 0.5975 - loss: 0.8821 - val_accuracy: 0.6271 - val_loss: 0.8327
# Epoch 6/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.5995 - loss: 0.8815 - val_accuracy: 0.6271 - val_loss: 0.8128
# Epoch 7/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.5734 - loss: 0.8641 - val_accuracy: 0.6271 - val_loss: 0.7895
# Epoch 8/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 195ms/step - accuracy: 0.5880 - loss: 0.8228 - val_accuracy: 0.6271 - val_loss: 0.7681
# Epoch 9/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 186ms/step - accuracy: 0.6245 - loss: 0.7960 - val_accuracy: 0.7119 - val_loss: 0.7527
# Epoch 10/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 189ms/step - accuracy: 0.7175 - loss: 0.7577 - val_accuracy: 0.7797 - val_loss: 0.7405
# Epoch 11/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 190ms/step - accuracy: 0.7931 - loss: 0.7302 - val_accuracy: 0.7966 - val_loss: 0.6891
# Epoch 12/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 187ms/step - accuracy: 0.8103 - loss: 0.6630 - val_accuracy: 0.7119 - val_loss: 0.6640
# Epoch 13/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 187ms/step - accuracy: 0.7149 - loss: 0.6421 - val_accuracy: 0.7627 - val_loss: 0.6352
# Epoch 14/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s
80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 203ms/step - accuracy: 0.9976 - loss: 0.0086 - val_accuracy: 0.8305 - val_loss: 0.8834
# Epoch 67/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.9986 - loss: 0.0068 - val_accuracy: 0.8305 - val_loss: 0.8858
# Epoch 68/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 236ms/step - accuracy: 0.9976 - loss: 0.0078 - val_accuracy: 0.8305 - val_loss: 0.8805
# Epoch 69/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 248ms/step - accuracy: 0.9976 - loss: 0.0072 - val_accuracy: 0.8305 - val_loss: 0.8736
# Epoch 70/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 196ms/step - accuracy: 0.9976 - loss: 0.0067 - val_accuracy: 0.8136 - val_loss: 0.8712
# Epoch 71/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 207ms/step - accuracy: 0.9976 - loss: 0.0074 - val_accuracy: 0.8136 - val_loss: 0.8723
# Epoch 72/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 197ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.8136 - val_loss: 0.8787
# Epoch 73/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 195ms/step - accuracy: 0.9986 - loss: 0.0055 - val_accuracy: 0.8136 - val_loss: 0.8877
# Epoch 74/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 240ms/step - accuracy: 0.9976 - loss: 0.0069 - val_accuracy: 0.8136 - val_loss: 0.9011
# Epoch 75/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 202ms/step - accuracy: 0.9976 - loss: 0.0066 - val_accuracy: 0.8136 - val_loss: 0.9161
# Epoch 76/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 207ms/step - accuracy: 0.9962 - loss: 0.0059 - val_accuracy: 0.7966 - val_loss: 0.9310
# Epoch 77/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 212ms/step - accuracy: 0.9986 - loss: 0.0054 - val_accuracy: 0.7966 - val_loss: 0.9447
# Epoch 78/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.7966 - val_loss: 0.9609
# Epoch 79/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 249ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.7966 - val_loss: 0.9777
# Epoch 80/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 191ms/step - accuracy: 0.9986 - loss: 0.0053 - val_accuracy: 0.7966 - val_loss: 0.9915
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7032 - loss: 1.4928
# Test Loss: 1.4671
# Test Accuracy: 0.7230
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# F1 Score: 0.7145
# Precision: 0.7120
# Recall: 0.7230

# %%
filter_sizes = [2,3,5]
num_filters = 32

inputs = Input(shape=(max_sequence_length,), dtype='int32')
embedding = Embedding(max_words, embedding_dim, input_length=max_sequence_length)(inputs)
reshape = Reshape((max_sequence_length,embedding_dim,1))(embedding)

conv_0 = Conv2D(num_filters, kernel_size=(filter_sizes[0], embedding_dim), padding='valid', kernel_initializer='normal', activation='elu')(reshape)
conv_1 = Conv2D(num_filters, kernel_size=(filter_sizes[1], embedding_dim), padding='valid', kernel_initializer='normal', activation='elu')(reshape)
conv_2 = Conv2D(num_filters, kernel_size=(filter_sizes[2], embedding_dim), padding='valid', kernel_initializer='normal', activation='elu')(reshape)

maxpool_0 = MaxPool2D(pool_size=(max_sequence_length - filter_sizes[0] + 1, 1), strides=(1,1), padding='valid')(conv_0)
maxpool_1 = MaxPool2D(pool_size=(max_sequence_length - filter_sizes[1] + 1, 1), strides=(1,1), padding='valid')(conv_1)
maxpool_2 = MaxPool2D(pool_size=(max_sequence_length - filter_sizes[2] + 1, 1), strides=(1,1), padding='valid')(conv_2)

concatenated_tensor = Concatenate(axis=1)([maxpool_0, maxpool_1, maxpool_2])
flatten = Flatten()(concatenated_tensor)
dropout = Dropout(drop)(flatten)
output = Dense(units=3, activation='softmax')(dropout)

model = Model(inputs=inputs, outputs=output)

model.summary()

adam = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, weight_decay=0.0)

model.compile(optimizer=adam, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history = model.fit(X_train_padded, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)

test_loss, test_accuracy = model.evaluate(X_test_padded, y_test, verbose=1)
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy:.4f}')

y_test_pred = model.predict(X_test_padded)
y_test_pred_classes = np.argmax(y_test_pred, axis=1)

f1 = f1_score(y_test, y_test_pred_classes, average='weighted')
precision = precision_score(y_test, y_test_pred_classes, average='weighted')
recall = recall_score(y_test, y_test_pred_classes, average='weighted')
print(f'F1 Score: {f1:.4f}')
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 100)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_2         │ (None, 100, 100)  │  1,000,000 │ input_layer_2[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 100, 100,  │          0 │ embedding_2[0][0] │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 99, 1, 32) │      6,432 │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 98, 1, 32) │      9,632 │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 96, 1, 32) │     16,032 │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 1, 1, 32)  │          0 │ conv2d[0][0]      │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 1, 1, 32)  │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 1, 1, 32)  │          0 │ conv2d_2[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 3, 1, 32)  │          0 │ max_pooling2d[0]… │
# │ (Concatenate)       │                   │            │ max_pooling2d_1[… │
# │                     │                   │            │ max_pooling2d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 96)        │          0 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 96)        │          0 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 3)         │        291 │ dropout_2[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,032,387 (3.94 MB)
#  Trainable params: 1,032,387 (3.94 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 278ms/step - accuracy: 0.3660 - loss: 1.0942 - val_accuracy: 0.6102 - val_loss: 1.0288
# Epoch 2/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 156ms/step - accuracy: 0.5648 - loss: 1.0221 - val_accuracy: 0.6610 - val_loss: 0.9716
# Epoch 3/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.6380 - loss: 0.9644 - val_accuracy: 0.6441 - val_loss: 0.9232
# Epoch 4/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.6332 - loss: 0.9196 - val_accuracy: 0.6271 - val_loss: 0.8824
# Epoch 5/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.6234 - loss: 0.8857 - val_accuracy: 0.6271 - val_loss: 0.8483
# Epoch 6/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.6206 - loss: 0.8421 - val_accuracy: 0.6271 - val_loss: 0.8188
# Epoch 7/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.6229 - loss: 0.8296 - val_accuracy: 0.6271 - val_loss: 0.7974
# Epoch 8/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.6350 - loss: 0.7956 - val_accuracy: 0.6271 - val_loss: 0.7815
# Epoch 9/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.6017 - loss: 0.7992 - val_accuracy: 0.6271 - val_loss: 0.7703
# Epoch 10/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.6321 - loss: 0.7869 - val_accuracy: 0.6441 - val_loss: 0.7613
# Epoch 11/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.6598 - loss: 0.7633 - val_accuracy: 0.6780 - val_loss: 0.7538
# Epoch 12/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.6899 - loss: 0.7379 - val_accuracy: 0.6949 - val_loss: 0.7472
# Epoch 13/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.7359 - loss: 0.7181 - val_accuracy: 0.7119 - val_loss: 0.7420
# Epoch 14/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.7603 - loss: 0.7031 - val_accuracy: 0.7288 - val_loss: 0.7366
# Epoch 15/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8102 - loss: 0.6775 - val_accuracy: 0.7288 - val_loss: 0.7284
# Epoch 16/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.8166 - loss: 0.6511 - val_accuracy: 0.7119 - val_loss: 0.7195
# Epoch 17/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.8467 - loss: 0.6354 - val_accuracy: 0.7119 - val_loss: 0.7114
# Epoch 18/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0